# %%
#!pip install config
#!pip install beautifulsoup4

import pandas as pd
import numpy as np
import requests
import bs4
import urllib3
import config
import time
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq

#!pip install selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# Remove request warnings
urllib3.disable_warnings()

agent = {"User-Agent":"Mozilla/5.0"}

# %%
company_names = []
employee_number = []
revenues = []
net_income_growths = []
enviornmental_social_governance_rankings = []
managing_directors = []
board_chairmans = []
directors = []
subsidiaries_number = []


link = 'https://www.dnb.com/business-directory/company-profiles.compagnie_financiere_richemont_sa.dc0156d49253885e64102460d6cdcd77.html'
time.sleep(8)
option = webdriver.ChromeOptions()
time.sleep(8)
driver = webdriver.Chrome("/Users/cirillogirardi/Downloads/chromedriver", options=option)
time.sleep(6)
driver.get(link)

data = driver.find_elements_by_class_name('company-profile-header-title')
company_name = data[0].text
company_names.append(company_name)

info = driver.find_elements_by_xpath("//span[@class='company_data_point']/span")
employees = info[11].text
employee_number.append(employees)

revenue = info[12].text
revenues.append(revenue)

net_income_growth = info[14].text
net_income_growths.append(net_income_growth)

enviornmental_social_governance_ranking = info[20].text
enviornmental_social_governance_rankings.append(enviornmental_social_governance_ranking)


names = driver.find_elements_by_class_name("name")
managing_director = names[0].text
managing_directors.append(managing_director)

board_chairman = names[1].text
board_chairmans.append(board_chairman)

director = names[2].text
directors.append(director)

sub = driver.find_elements_by_class_name('company_name')
subsidiaries = sub[1].text
subsidiaries_number.append(subsidiaries)
# Out:
# /var/folders/t8/_1lw_ywx6bzftgb05dh9ty280000gn/T/ipykernel_27937/3797621010.py:16: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("/Users/cirillogirardi/Downloads/chromedriver", options=option)
# /var/folders/t8/_1lw_ywx6bzftgb05dh9ty280000gn/T/ipykernel_27937/3797621010.py:20: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   data = driver.find_elements_by_class_name('company-profile-header-title')
# /var/folders/t8/_1lw_ywx6bzftgb05dh9ty280000gn/T/ipykernel_27937/3797621010.py:24: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   info = driver.find_elements_by_xpath("//span[@class='company_data_point']/span")
# /var/folders/t8/_1lw_ywx6bzftgb05dh9ty280000gn/T/ipykernel_27937/3797621010.py:38: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   names = driver.find_elements_by_class_name("name")
# /var/folders/t8/_1lw_ywx6bzftgb05dh9ty280000gn/T/ipykernel_27937/3797621010.py:48: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   sub = driver.find_elements_by_class_name('company_name')

# %%
a_link = 'https://www.dnb.com/business-directory/company-profiles.audemars_piguet_holding_sa.68acd45e712da185227042edb4487a38.html'
time.sleep(8)
option = webdriver.ChromeOptions()
time.sleep(8)
driver = webdriver.Chrome("/Users/cirillogirardi/Downloads/chromedriver", options=option)
time.sleep(6)
driver.get(a_link)

data = driver.find_elements_by_class_name('company-profile-header-title')
a_company_name = data[0].text
company_names.append(a_company_name)

info = driver.find_elements_by_xpath("//span[@class='company_data_point']/span")
a_employees = info[12].text
employee_number.append(a_employees)

a_revenue = info[13].text
revenues.append(a_revenue)

a_net_income_growth = 'null'
net_income_growths.append(a_net_income_growth)

a_enviornmental_social_governance_ranking = info[16].text
enviornmental_social_governance_rankings.append(a_enviornmental_social_governance_ranking)

names = driver.find_elements_by_class_name("name")
a_managing_director = names[0].text
managing_directors.append(a_managing_director)

a_board_chairman = names[1].text
board_chairmans.append(a_board_chairman)

a_director = names[2].text
directors.append(a_director)

sub = driver.find_elements_by_class_name('company_name')
a_subsidiaries = sub[1].text
subsidiaries_number.append(a_subsidiaries)
# Out:
# /var/folders/t8/_1lw_ywx6bzftgb05dh9ty280000gn/T/ipykernel_27937/3518793153.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("/Users/cirillogirardi/Downloads/chromedriver", options=option)
# /var/folders/t8/_1lw_ywx6bzftgb05dh9ty280000gn/T/ipykernel_27937/3518793153.py:9: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   data = driver.find_elements_by_class_name('company-profile-header-title')
# /var/folders/t8/_1lw_ywx6bzftgb05dh9ty280000gn/T/ipykernel_27937/3518793153.py:13: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   info = driver.find_elements_by_xpath("//span[@class='company_data_point']/span")
# /var/folders/t8/_1lw_ywx6bzftgb05dh9ty280000gn/T/ipykernel_27937/3518793153.py:26: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   names = driver.find_elements_by_class_name("name")
# /var/folders/t8/_1lw_ywx6bzftgb05dh9ty280000gn/T/ipykernel_27937/3518793153.py:36: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   sub = driver.find_elements_by_class_name('company_name')

# %%
company_financial_df = pd.DataFrame({'holding_company': company_names,
                                    'employees': employee_number,
                                    'revenue': revenues,
                                    'net_income_growth': net_income_growths,
                                    'enviornmental_social_governance_ranking': enviornmental_social_governance_rankings,
                                    'managing_director': managing_directors,
                                    'board_chairman': board_chairmans,
                                    'director': directors,
                                    'subsidiaries': subsidiaries_number
                                    })

company_financial_df
# Out:
#                      holding_company employees          revenue  \
# 0  COMPAGNIE FINANCIERE RICHEMONT SA    34,760   $15.96 billion
# 1       Audemars Piguet Holding S.A.       900  $160.12 million
#
#   net_income_growth enviornmental_social_governance_ranking  \
# 0            39.44%                                     3.0
# 1              null                                     1.0
#
#            managing_director    board_chairman          director  \
# 0             Jérôme Lambert     Johann Rupert    Cédric Bossert
# 1  François-Henri Bennahmias  Jasmine Audemars  Nicolas Burgener
#
#        subsidiaries
# 0  145 Subsidiaries
# 1   19 Subsidiaries

# %%
company_financial_df.holding_company = company_financial_df.holding_company.str.title()

# %%
company_financial_df
# Out:
#                      holding_company employees          revenue  \
# 0  Compagnie Financiere Richemont Sa    34,760   $15.96 billion
# 1       Audemars Piguet Holding S.A.       900  $160.12 million
#
#   net_income_growth enviornmental_social_governance_ranking  \
# 0            39.44%                                     3.0
# 1              null                                     1.0
#
#            managing_director    board_chairman          director  \
# 0             Jérôme Lambert     Johann Rupert    Cédric Bossert
# 1  François-Henri Bennahmias  Jasmine Audemars  Nicolas Burgener
#
#        subsidiaries
# 0  145 Subsidiaries
# 1   19 Subsidiaries

# %%
import pyarrow

# %%
company_financial_df.to_parquet('financial_information.parquet')

# %%
company_financial_df.to_csv('financial_information.csv')
