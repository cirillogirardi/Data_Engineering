# %% [markdown]
# # Watches of Switzerland

# %%
# install necessary packages and import them as needed

#!pip install config
#!pip install beautifulsoup4

import pandas as pd
import numpy as np
import requests
import bs4
import urllib3
import config
import time
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq

# Remove request warnings
urllib3.disable_warnings()


#define the agent for the web scraping
agent = {"User-Agent":"Mozilla/5.0"}

# %%
# define the lists to contain the watches' websites
website_pages = []
# define the initial link to get the href for the watches
website = "https://www.watches-of-switzerland.co.uk/c/Brands/Audemars-Piguet?q=%3Arelevance&page=0"
# get access using the specified criteria
website_access = requests.get(website, verify=True, headers=agent)
time.sleep(1)
# scrape the website using beautiful soup using an html parser
website_soup = soup(website_access.text, 'html.parser')
# create a wrap to find the links for the individual watches
time.sleep(1)
website_wrap = website_soup.find_all('a', {'href': lambda value: value and value.startswith('/Audemars-Piguet')})
#set a loop to get the links and append them to the list
for i in range(0, (len(website_wrap)-1)):
    website_pages.append(website_wrap[i].get("href"))
website_pages
# Out:
# ['/Audemars-Piguet-Royal-Oak-Offshore-26420TI.OO.A027CA.01/p/17580962',
#  '/Audemars-Piguet-Royal-Oak-Offshore-26420SO.OO.A600CA.01/p/17580961',
#  '/Audemars-Piguet-Royal-Oak-Offshore-26420SO.OO.A002CA.01/p/17580960',
#  '/Audemars-Piguet-Royal-Oak-Offshore-26420RO.OO.A002CA.01/p/17580959',
#  '/Audemars-Piguet-Royal-Oak-Offshore-26420IO.OO.A009CA.01/p/17580958',
#  '/Audemars-Piguet-Royal-Oak-Diver-Offshore-15720ST.OO.A052CA.01/p/17580945',
#  '/Audemars-Piguet-Royal-Oak-Diver-Offshore-15720ST.OO.A027CA.01/p/17580910',
#  '/Audemars-Piguet-Royal-Oak-Diver-Offshore-15720ST.OO.A009CA.01/p/17580909',
#  '/Audemars-Piguet-Royal-Oak-67651OR.ZZ.1261OR.02/p/17580896',
#  '/Audemars-Piguet-Royal-Oak-Offshore-Chronograph-26231OR.ZZ.D003CA.01/p/17580888',
#  '/Audemars-Piguet-Royal-Oak-Offshore-Chronograph-26231ST.ZZ.D027CA.01/p/17580887',
#  '/Audemars-Piguet-Royal-Oak-77351ST.ZZ.1261ST.01/p/17580873',
#  '/Audemars-Piguet-Royal-Oak-77351OR.ZZ.1261OR.01/p/17580872',
# ...

# %%
# define the lists to contain the scraped information
watch_code = []
watch_guarantee = []
watch_category = []
watch_markers = []
watch_strap =  []
watch_recipient = [] 
watch_movement = []
watch_dial = []
watch_case = []
watch_collection = []
watch_reference = []
watch_price = []
watch_brand = []

# create a loop to iterate through 5 observations
for c in website_pages[0:5]:
    # get the link utilizing the list created before, access the link and connect with soup 
    AP_link = "https://www.watches-of-switzerland.co.uk" + c
    AP_access = requests.get(AP_link, verify=False, headers=agent)
    time.sleep(5)
    AP_soup = soup(AP_access.text, 'html.parser')   
    # find the table of information for each watch
    time.sleep(6)
    # create a wrap to find the needed information
    AP_table = AP_soup.find_all('span', {'class': 'specValue'})
    
    code = (AP_table[0]).text
    watch_code.append(code)
    
    guarantee = (AP_table[1]).text
    watch_guarantee.append(guarantee)
    
    category = (AP_table[2]).text
    watch_category.append(category)
    
    markers = (AP_table[4]).text
    watch_markers.append(markers)
    
    strap = (AP_table[5]).text
    watch_strap.append(strap)
    
    recipient = (AP_table[6]).text
    watch_recipient.append(recipient)
    
    movement = (AP_table[7]).text
    watch_movement.append(movement)
    
    dial_color = (AP_table[8]).text
    watch_dial.append(dial_color)
    
    case_material = (AP_table[9]).text
    watch_case.append(case_material)
    
    collection = (AP_table[10]).text
    watch_collection.append(collection)
    
    # create a wrap to find the needed information
    AP_spec = AP_soup.find_all('span',{'class': 'productManCode'})
    
    reference = AP_spec[0].text
    watch_reference.append(reference)
    
    # create a wrap to find the needed information
    AP_price = AP_soup.find_all('span',{'class': 'productPrice'})
    
    price = AP_price[0].get_text(strip=True)
    watch_price.append(price)
    
    # create a wrap to find the needed information
    AP_brand = AP_soup.find_all('span',{'class': 'productBrandName'})
    
    brand = AP_brand[0].get_text(strip=True)
    watch_brand.append(brand)

# %%
# create a dataframe and name the columns

AP_watch_df0 = pd.DataFrame({'watch_code': watch_code,
                        'watch_brand':watch_brand,
                        'watch_collection': watch_collection,
                        'watch_reference': watch_reference,
                        'watch_price': watch_price,
                        'watch_movement': watch_movement,
                        'watch_case': watch_case,
                        'watch_dial': watch_dial,
                        'watch_strap': watch_strap,
                        'watch_markers': watch_markers,
                        'watch_guarantee': watch_guarantee,
                        'watch_category': watch_category,
                        'watch_recipient': watch_recipient
                       })
AP_watch_df0
# Out:
#   watch_code      watch_brand    watch_collection       watch_reference  \
# 0   17580962  Audemars Piguet  Royal Oak Offshore  26420TI.OO.A027CA.01
# 1   17580961  Audemars Piguet  Royal Oak Offshore  26420SO.OO.A600CA.01
# 2   17580960  Audemars Piguet  Royal Oak Offshore  26420SO.OO.A002CA.01
# 3   17580959  Audemars Piguet  Royal Oak Offshore  26420RO.OO.A002CA.01
# 4   17580958  Audemars Piguet  Royal Oak Offshore  26420IO.OO.A009CA.01
#
#   watch_price watch_movement                 watch_case watch_dial  \
# 0  £33,000.00      Automatic                   Titanium       Blue
# 1  £34,100.00      Automatic  Ceramic & Stainless Steel      Brown
# 2  £34,100.00      Automatic  Ceramic & Stainless Steel      Black
# 3  £51,100.00      Automatic   Ceramic & 18ct Rose Gold      Black
# 4  £34,100.00      Automatic                       null       Grey
#
#   watch_strap watch_markers                   watch_guarantee watch_category  \
# ...

# %%
# define the lists to contain the scraped information

watch_code1 = []
watch_guarantee1 = []
watch_category1 = []
watch_markers1 = []
watch_strap1 =  []
watch_recipient1 = [] 
watch_movement1 = []
watch_dial1 = []
watch_case1 = []
watch_collection1 = []
watch_reference1 = []
watch_price1 = []
watch_brand1 = []

# create a loop to iterate through next 3 observations
for c in website_pages[5:8]:
     # get the link utilizing the list created before, access the link and connect with soup 
    AP_link = "https://www.watches-of-switzerland.co.uk" + c
    AP_access = requests.get(AP_link, verify=False, headers=agent)
    time.sleep(5)
    AP_soup = soup(AP_access.text, 'html.parser')   
    # find the table of information for each watch
    time.sleep(6)
    # create a wrap to find the needed information
    AP_table = AP_soup.find_all('span', {'class': 'specValue'})
    
    code = (AP_table[0]).text
    watch_code1.append(code)
    
    guarantee = (AP_table[1]).text
    watch_guarantee1.append(guarantee)
    
    category = (AP_table[2]).text
    watch_category1.append(category)
    
    markers = (AP_table[4]).text
    watch_markers1.append(markers)
    
    strap = (AP_table[6]).text
    watch_strap1.append(strap)
    
    recipient = (AP_table[7]).text
    watch_recipient1.append(recipient)
    
    movement = (AP_table[8]).text
    watch_movement1.append(movement)
    
    dial_color = (AP_table[9]).text
    watch_dial1.append(dial_color)
    
    case_material = (AP_table[10]).text
    watch_case1.append(case_material)
    
    collection = (AP_table[11]).text
    watch_collection1.append(collection)
    
    # create a wrap to find the needed information
    AP_spec = AP_soup.find_all('span',{'class': 'productManCode'})
    
    reference = AP_spec[0].text
    watch_reference1.append(reference)
    
    # create a wrap to find the needed information
    AP_price = AP_soup.find_all('span',{'class': 'productPrice'})
    
    price = AP_price[0].get_text(strip=True)
    watch_price1.append(price)
    
    # create a wrap to find the needed information
    AP_brand = AP_soup.find_all('span',{'class': 'productBrandName'})
    
    brand = AP_brand[0].get_text(strip=True)
    watch_brand1.append(brand)

# %%
# create a dataframe and name the columns

AP_watch_df1 = pd.DataFrame({'watch_code': watch_code1,
                        'watch_brand':watch_brand1,
                        'watch_collection': watch_collection1,
                        'watch_reference': watch_reference1,
                        'watch_price': watch_price1,
                        'watch_movement': watch_movement1,
                        'watch_case': watch_case1,
                        'watch_dial': watch_dial1,
                        'watch_strap': watch_strap1,
                        'watch_markers': watch_markers1,
                        'watch_guarantee': watch_guarantee1,
                        'watch_category': watch_category1,
                        'watch_recipient': watch_recipient1
                       })
AP_watch_df1
# Out:
#   watch_code      watch_brand          watch_collection       watch_reference  \
# 0   17580945  Audemars Piguet  Royal Oak Diver Offshore  15720ST.OO.A052CA.01
# 1   17580910  Audemars Piguet  Royal Oak Diver Offshore  15720ST.OO.A027CA.01
# 2   17580909  Audemars Piguet  Royal Oak Diver Offshore  15720ST.OO.A009CA.01
#
#   watch_price watch_movement       watch_case watch_dial watch_strap  \
# 0  £23,100.00      Automatic  Stainless Steel      Green      Rubber
# 1  £23,100.00      Automatic  Stainless Steel       Navy      Rubber
# 2  £23,100.00      Automatic  Stainless Steel       Grey      Rubber
#
#   watch_markers                   watch_guarantee watch_category  \
# 0        Batons  Audemars Piguet 2 Year Guarantee        Watches
# 1        Batons  Audemars Piguet 2 Year Guarantee        Watches
# 2        Batons  Audemars Piguet 2 Year Guarantee        Watches
#
#   watch_recipient
# 0         For Him
# 1         For Him
# 2         For Him

# %%
# define the lists to contain the scraped information

watch_code2 = []
watch_guarantee2 = []
watch_category2 = []
watch_markers2 = []
watch_strap2 =  []
watch_recipient2 = [] 
watch_movement2 = []
watch_dial2 = []
watch_case2 = []
watch_collection2 = []
watch_reference2 = []
watch_price2 = []
watch_brand2 = []

# create a loop to iterate through next 3 observations
for c in website_pages[9:11]:
     # get the link utilizing the list created before, access the link and connect with soup 
    AP_link = "https://www.watches-of-switzerland.co.uk" + c
    AP_access = requests.get(AP_link, verify=False, headers=agent)
    time.sleep(5)
    AP_soup = soup(AP_access.text, 'html.parser')   
    # find the table of information for each watch
    time.sleep(6)
    # create a wrap to find the needed information
    AP_table = AP_soup.find_all('span', {'class': 'specValue'})
    
    code = (AP_table[0]).text
    watch_code2.append(code)
    
    guarantee = (AP_table[1]).text
    watch_guarantee2.append(guarantee)
    
    category = (AP_table[2]).text
    watch_category2.append(category)
    
    markers = (AP_table[4]).text
    watch_markers2.append(markers)
    
    strap = (AP_table[5]).text
    watch_strap2.append(strap)
    
    recipient = (AP_table[6]).text
    watch_recipient2.append(recipient)
    
    movement = (AP_table[7]).text
    watch_movement2.append(movement)
    
    dial_color = (AP_table[8]).text
    watch_dial2.append(dial_color)
    
    case_material = (AP_table[9]).text
    watch_case2.append(case_material)
    
    collection = (AP_table[10]).text
    watch_collection2.append(collection)
    
    # create a wrap to find the needed information
    AP_spec = AP_soup.find_all('span',{'class': 'productManCode'})
    
    reference = AP_spec[0].text
    watch_reference2.append(reference)
    
    # create a wrap to find the needed information
    AP_price = AP_soup.find_all('span',{'class': 'productPrice'})
    
    price = AP_price[0].get_text(strip=True)
    watch_price2.append(price)
    
    # create a wrap to find the needed information
    AP_brand = AP_soup.find_all('span',{'class': 'productBrandName'})
    
    brand = AP_brand[0].get_text(strip=True)
    watch_brand2.append(brand)

# %%
# create a dataframe and name the columns

AP_watch_df2 = pd.DataFrame({'watch_code': watch_code2,
                        'watch_brand':watch_brand2,
                        'watch_collection': watch_collection2,
                        'watch_reference': watch_reference2,
                        'watch_price': watch_price2,
                        'watch_movement': watch_movement2,
                        'watch_case': watch_case2,
                        'watch_dial': watch_dial2,
                        'watch_strap': watch_strap2,
                        'watch_markers': watch_markers2,
                        'watch_guarantee': watch_guarantee2,
                        'watch_category': watch_category2,
                        'watch_recipient': watch_recipient2
                       })
AP_watch_df2
# Out:
#   watch_code      watch_brand    watch_collection       watch_reference  \
# 0   17580888  Audemars Piguet  Royal Oak Offshore  26231OR.ZZ.D003CA.01
# 1   17580887  Audemars Piguet  Royal Oak Offshore  26231ST.ZZ.D027CA.01
#
#   watch_price watch_movement       watch_case watch_dial watch_strap  \
# 0  £44,700.00      Automatic   18ct Rose Gold     Silver      Rubber
# 1  £30,300.00      Automatic  Stainless Steel       Blue      Rubber
#
#   watch_markers                   watch_guarantee watch_category  \
# 0        Batons  Audemars Piguet 2 Year Guarantee        Watches
# 1        Batons  Audemars Piguet 2 Year Guarantee        Watches
#
#   watch_recipient
# 0         For Her
# 1         For Her

# %%
# define the lists to contain the scraped information

watch_codem = []
watch_guaranteem = []
watch_categorym = []
watch_markersm = []
watch_strapm =  []
watch_recipientm = [] 
watch_movementm = []
watch_dialm = []
watch_casem = []
watch_collectionm = []
watch_referencem = []
watch_pricem = []
watch_brandm = []

# create a loop to iterate through next 2 observations
for c in website_pages[11:13]:
     # get the link utilizing the list created before, access the link and connect with soup 
    AP_link = "https://www.watches-of-switzerland.co.uk" + c
    AP_access = requests.get(AP_link, verify=False, headers=agent)
    time.sleep(5)
    AP_soup = soup(AP_access.text, 'html.parser')   
    # find the table of information for each watch
    time.sleep(6)
    # create a wrap to find the needed information
    AP_table = AP_soup.find_all('span', {'class': 'specValue'})
    
    code = (AP_table[0]).text
    watch_codem.append(code)
    
    guarantee = (AP_table[1]).text
    watch_guaranteem.append(guarantee)
    
    category = (AP_table[2]).text
    watch_categorym.append(category)
    
    markers = 'null'
    watch_markersm.append(markers)
    
    strap = (AP_table[5]).text
    watch_strapm.append(strap)
    
    recipient = (AP_table[6]).text
    watch_recipientm.append(recipient)
    
    movement = (AP_table[7]).text
    watch_movementm.append(movement)
    
    dial_color = (AP_table[8]).text
    watch_dialm.append(dial_color)
    
    case_material = (AP_table[9]).text
    watch_casem.append(case_material)
    
    collection = (AP_table[11]).text
    watch_collectionm.append(collection)
    
    # create a wrap to find the needed information
    AP_spec = AP_soup.find_all('span',{'class': 'productManCode'})
    
    reference = AP_spec[0].text
    watch_referencem.append(reference)
    
    # create a wrap to find the needed information
    AP_price = AP_soup.find_all('span',{'class': 'productPrice'})
    
    price = AP_price[0].get_text(strip=True)
    watch_pricem.append(price)
    
    # create a wrap to find the needed information
    AP_brand = AP_soup.find_all('span',{'class': 'productBrandName'})
    
    brand = AP_brand[0].get_text(strip=True)
    watch_brandm.append(brand)

# %%
# create a dataframe and name the columns

AP_watch_dfm = pd.DataFrame({'watch_code': watch_codem,
                        'watch_brand':watch_brandm,
                        'watch_collection': watch_collectionm,
                        'watch_reference': watch_referencem,
                        'watch_price': watch_pricem,
                        'watch_movement': watch_movementm,
                        'watch_case': watch_casem,
                        'watch_dial': watch_dialm,
                        'watch_strap': watch_strapm,
                        'watch_markers': watch_markersm,
                        'watch_guarantee': watch_guaranteem,
                        'watch_category': watch_categorym,
                        'watch_recipient': watch_recipientm
                       })
AP_watch_dfm
# Out:
#   watch_code      watch_brand watch_collection       watch_reference  \
# 0   17580873  Audemars Piguet        Royal Oak  77351ST.ZZ.1261ST.01
# 1   17580872  Audemars Piguet        Royal Oak  77351OR.ZZ.1261OR.01
#
#   watch_price watch_movement      watch_case watch_dial     watch_strap  \
# 0  £24,600.00      Automatic  18ct Rose Gold     Silver  18ct Rose Gold
# 1  £46,400.00      Automatic  18ct Rose Gold     Silver  18ct Rose Gold
#
#   watch_markers                   watch_guarantee watch_category  \
# 0          null  Audemars Piguet 2 Year Guarantee        Watches
# 1          null  Audemars Piguet 2 Year Guarantee        Watches
#
#   watch_recipient
# 0         For Her
# 1         For Her

# %%
# define the lists to contain the scraped information

watch_code3 = []
watch_guarantee3 = []
watch_category3 = []
watch_markers3 = []
watch_strap3 =  []
watch_recipient3 = [] 
watch_movement3 = []
watch_dial3 = []
watch_case3 = []
watch_collection3 = []
watch_reference3 = []
watch_price3 = []
watch_brand3 = []

# create a loop to iterate through next 2 observations
for c in website_pages[13:15]:
     # get the link utilizing the list created before, access the link and connect with soup 
    AP_link = "https://www.watches-of-switzerland.co.uk" + c
    AP_access = requests.get(AP_link, verify=False, headers=agent)
    time.sleep(5)
    AP_soup = soup(AP_access.text, 'html.parser')   
    # find the table of information for each watch
    time.sleep(6)
    # create a wrap to find the needed information
    AP_table = AP_soup.find_all('span', {'class': 'specValue'})
    
    code = (AP_table[0]).text
    watch_code3.append(code)
    
    guarantee = (AP_table[1]).text
    watch_guarantee3.append(guarantee)
    
    category = (AP_table[2]).text
    watch_category3.append(category)
    
    markers = (AP_table[4]).text
    watch_markers3.append(markers)
    
    strap = (AP_table[6]).text
    watch_strap3.append(strap)
    
    recipient = (AP_table[7]).text
    watch_recipient3.append(recipient)
    
    movement = (AP_table[8]).text
    watch_movement3.append(movement)
    
    dial_color = (AP_table[9]).text
    watch_dial3.append(dial_color)
    
    case_material = (AP_table[10]).text
    watch_case3.append(case_material)
    
    collection = (AP_table[11]).text
    watch_collection3.append(collection)
    
    # create a wrap to find the needed information
    AP_spec = AP_soup.find_all('span',{'class': 'productManCode'})
    
    reference = AP_spec[0].text
    watch_reference3.append(reference)
    
    # create a wrap to find the needed information
    AP_price = AP_soup.find_all('span',{'class': 'productPrice'})
    
    price = AP_price[0].get_text(strip=True)
    watch_price3.append(price)
    
    # create a wrap to find the needed information
    AP_brand = AP_soup.find_all('span',{'class': 'productBrandName'})
    
    brand = AP_brand[0].get_text(strip=True)
    watch_brand3.append(brand)

# %%
# create a dataframe and name the columns

AP_watch_df3 = pd.DataFrame({'watch_code': watch_code3,
                        'watch_brand':watch_brand3,
                        'watch_collection': watch_collection3,
                        'watch_reference': watch_reference3,
                        'watch_price': watch_price3,
                        'watch_movement': watch_movement3,
                        'watch_case': watch_case3,
                        'watch_dial': watch_dial3,
                        'watch_strap': watch_strap3,
                        'watch_markers': watch_markers3,
                        'watch_guarantee': watch_guarantee3,
                        'watch_category': watch_category3,
                        'watch_recipient': watch_recipient3
                       })
AP_watch_df3
# Out:
#   watch_code      watch_brand watch_collection       watch_reference  \
# 0   17580869  Audemars Piguet        Royal Oak  15500OR.OO.D002CR.01
# 1   17580868  Audemars Piguet        Royal Oak  15500OR.OO.1220OR.01
#
#   watch_price watch_movement      watch_case watch_dial     watch_strap  \
# 0  £33,800.00      Automatic  18ct Rose Gold      Black       Alligator
# 1  £52,800.00      Automatic  18ct Rose Gold      Black  18ct Rose Gold
#
#   watch_markers                   watch_guarantee watch_category  \
# 0        Batons  Audemars Piguet 2 Year Guarantee        Watches
# 1        Batons  Audemars Piguet 2 Year Guarantee        Watches
#
#   watch_recipient
# 0         For Him
# 1         For Him

# %%
# define the lists to contain the scraped information

watch_code4 = []
watch_guarantee4 = []
watch_category4 = []
watch_markers4 = []
watch_strap4 =  []
watch_recipient4 = [] 
watch_movement4 = []
watch_dial4 = []
watch_case4 = []
watch_collection4 = []
watch_reference4 = []
watch_price4 = []
watch_brand4 = []

# create a loop to iterate through next 2 observations
for c in website_pages[15:17]:
     # get the link utilizing the list created before, access the link and connect with soup 
    AP_link = "https://www.watches-of-switzerland.co.uk" + c
    AP_access = requests.get(AP_link, verify=False, headers=agent)
    time.sleep(5)
    AP_soup = soup(AP_access.text, 'html.parser')   
    # find the table of information for each watch
    time.sleep(6)
    # create a wrap to find the needed information
    AP_table = AP_soup.find_all('span', {'class': 'specValue'})
    
    code = (AP_table[0]).text
    watch_code4.append(code)
    
    guarantee = (AP_table[1]).text
    watch_guarantee4.append(guarantee)
    
    category = (AP_table[2]).text
    watch_category4.append(category)
    
    markers = 'null'
    watch_markers4.append(markers)
    
    strap = (AP_table[5]).text
    watch_strap4.append(strap)
    
    recipient = (AP_table[6]).text
    watch_recipient4.append(recipient)
    
    movement = (AP_table[7]).text
    watch_movement4.append(movement)
    
    dial_color = (AP_table[8]).text
    watch_dial4.append(dial_color)
    
    case_material = (AP_table[9]).text
    watch_case4.append(case_material)
    
    collection = (AP_table[11]).text
    watch_collection4.append(collection)
    
    # create a wrap to find the needed information
    AP_spec = AP_soup.find_all('span',{'class': 'productManCode'})
    
    reference = AP_spec[0].text
    watch_reference4.append(reference)
    
    # create a wrap to find the needed information
    AP_price = AP_soup.find_all('span',{'class': 'productPrice'})
    
    price = AP_price[0].get_text(strip=True)
    watch_price4.append(price)
    
    # create a wrap to find the needed information
    AP_brand = AP_soup.find_all('span',{'class': 'productBrandName'})
    
    brand = AP_brand[0].get_text(strip=True)
    watch_brand4.append(brand)

# %%
# create a dataframe and name the columns

AP_watch_df4 = pd.DataFrame({'watch_code': watch_code4,
                        'watch_brand':watch_brand4,
                        'watch_collection': watch_collection4,
                        'watch_reference': watch_reference4,
                        'watch_price': watch_price4,
                        'watch_movement': watch_movement4,
                        'watch_case': watch_case4,
                        'watch_dial': watch_dial4,
                        'watch_strap': watch_strap4,
                        'watch_markers': watch_markers4,
                        'watch_guarantee': watch_guarantee4,
                        'watch_category': watch_category4,
                        'watch_recipient': watch_recipient4
                       })
AP_watch_df4
# Out:
#   watch_code      watch_brand watch_collection       watch_reference  \
# 0   17580867  Audemars Piguet        Royal Oak  77350ST.OO.1261ST.01
# 1   17580866  Audemars Piguet        Royal Oak  77350SR.OO.1261SR.01
#
#   watch_price watch_movement       watch_case watch_dial      watch_strap  \
# 0  £19,200.00      Automatic  Stainless Steel     Silver  Stainless Steel
# 1  £22,600.00      Automatic  Stainless Steel     Silver  Stainless Steel
#
#   watch_markers                   watch_guarantee watch_category  \
# 0          null  Audemars Piguet 2 Year Guarantee        Watches
# 1          null  Audemars Piguet 2 Year Guarantee        Watches
#
#   watch_recipient
# 0         For Her
# 1         For Her

# %%
# define the lists to contain the scraped information

watch_code5 = []
watch_guarantee5 = []
watch_category5 = []
watch_markers5 = []
watch_strap5 =  []
watch_recipient5 = [] 
watch_movement5 = []
watch_dial5 = []
watch_case5 = []
watch_collection5 = []
watch_reference5 = []
watch_price5 = []
watch_brand5 = []

# create a loop to iterate through next 4 observations
for c in website_pages[17:21]:
     # get the link utilizing the list created before, access the link and connect with soup 
    AP_link = "https://www.watches-of-switzerland.co.uk" + c
    AP_access = requests.get(AP_link, verify=False, headers=agent)
    time.sleep(5)
    AP_soup = soup(AP_access.text, 'html.parser')   
    # find the table of information for each watch
    time.sleep(6)
    AP_table = AP_soup.find_all('span', {'class': 'specValue'})
    
    code = (AP_table[0]).text
    watch_code5.append(code)
    
    guarantee = (AP_table[1]).text
    watch_guarantee5.append(guarantee)
    
    category = (AP_table[2]).text
    watch_category5.append(category)
    
    markers = (AP_table[4]).text
    watch_markers5.append(markers)
    
    strap = (AP_table[6]).text
    watch_strap5.append(strap)
    
    recipient = (AP_table[7]).text
    watch_recipient5.append(recipient)
    
    movement = (AP_table[8]).text
    watch_movement5.append(movement)
    
    dial_color = (AP_table[9]).text
    watch_dial5.append(dial_color)
    
    case_material = (AP_table[10]).text
    watch_case5.append(case_material)
    
    collection = (AP_table[12]).text
    watch_collection5.append(collection)
    
    # create a wrap to find the needed information
    AP_spec = AP_soup.find_all('span',{'class': 'productManCode'})
    
    reference = AP_spec[0].text
    watch_reference5.append(reference)
    
    # create a wrap to find the needed information
    AP_price = AP_soup.find_all('span',{'class': 'productPrice'})
    
    price = AP_price[0].get_text(strip=True)
    watch_price5.append(price)
    
    # create a wrap to find the needed information
    AP_brand = AP_soup.find_all('span',{'class': 'productBrandName'})
    
    brand = AP_brand[0].get_text(strip=True)
    watch_brand5.append(brand)

# %%
# create a dataframe and name the columns

AP_watch_df5 = pd.DataFrame({'watch_code': watch_code5,
                        'watch_brand':watch_brand5,
                        'watch_collection': watch_collection5,
                        'watch_reference': watch_reference5,
                        'watch_price': watch_price5,
                        'watch_movement': watch_movement5,
                        'watch_case': watch_case5,
                        'watch_dial': watch_dial5,
                        'watch_strap': watch_strap5,
                        'watch_markers': watch_markers5,
                        'watch_guarantee': watch_guarantee5,
                        'watch_category': watch_category5,
                        'watch_recipient': watch_recipient5
                       })
AP_watch_df5
# Out:
#   watch_code      watch_brand    watch_collection       watch_reference  \
# 0   17580806  Audemars Piguet  Royal Oak Offshore  26231ST.ZZ.D002CA.01
# 1   17580804  Audemars Piguet           Royal Oak  67650ST.OO.1261ST.01
# 2   17580803  Audemars Piguet           Royal Oak  67651SR.ZZ.1261SR.01
#
#   watch_price watch_movement       watch_case watch_dial      watch_strap  \
# 0  £30,300.00      Automatic  Stainless Steel      Black           Rubber
# 1  £13,800.00         Quartz  Stainless Steel      Black  Stainless Steel
# 2  £21,000.00         Quartz  Stainless Steel     Silver  Stainless Steel
#
#      watch_markers                   watch_guarantee watch_category  \
# 0           Batons  Audemars Piguet 2 Year Guarantee        Watches
# 1           Batons  Audemars Piguet 2 Year Guarantee        Watches
# 2  Arabic Numerals  Audemars Piguet 2 Year Guarantee        Watches
#
#   watch_recipient
# 0         For Her
# 1         For Her
# 2         For Her

# %%
# merge all dataframes together

AP = AP_watch_df0.append(AP_watch_df1)
AP = AP.append(AP_watch_df2)
AP = AP.append(AP_watch_dfm)
AP = AP.append(AP_watch_df3)
AP = AP.append(AP_watch_df4)
AP = AP.append(AP_watch_df5)
AP
# Out:
#   watch_code      watch_brand          watch_collection       watch_reference  \
# 0   17580962  Audemars Piguet        Royal Oak Offshore  26420TI.OO.A027CA.01
# 1   17580961  Audemars Piguet        Royal Oak Offshore  26420SO.OO.A600CA.01
# 2   17580960  Audemars Piguet        Royal Oak Offshore  26420SO.OO.A002CA.01
# 3   17580959  Audemars Piguet        Royal Oak Offshore  26420RO.OO.A002CA.01
# 4   17580958  Audemars Piguet        Royal Oak Offshore  26420IO.OO.A009CA.01
# 0   17580945  Audemars Piguet  Royal Oak Diver Offshore  15720ST.OO.A052CA.01
# 1   17580910  Audemars Piguet  Royal Oak Diver Offshore  15720ST.OO.A027CA.01
# 2   17580909  Audemars Piguet  Royal Oak Diver Offshore  15720ST.OO.A009CA.01
# 0   17580888  Audemars Piguet        Royal Oak Offshore  26231OR.ZZ.D003CA.01
# 1   17580887  Audemars Piguet        Royal Oak Offshore  26231ST.ZZ.D027CA.01
# 0   17580873  Audemars Piguet                 Royal Oak  77351ST.ZZ.1261ST.01
# ...

# %% [markdown]
# # Cartier

# %%
# for cartier

agent = {"User-Agent":"Mozilla/5.0"}

# define the lists to contain the watch websites
cartier_pages = []
# define the initial link to get the href for the watches
cartier = 'https://www.watches-of-switzerland.co.uk/c/Brands/Cartier?q=%3Arelevance&page=0'
# get access using the specified criteria
cartier_access = requests.get(cartier, verify=True, headers=agent)
time.sleep(1)
# scrape the website using beautiful soup using an html parser
cartier_soup = soup(cartier_access.text, 'html.parser')
# create a wrap to find the links for the individual watches
time.sleep(1)
cartier_wrap = cartier_soup.find_all('a', {'href': lambda value: value and value.startswith('/Cartier')})
# append the links to the list
for i in range(0, (len(cartier_wrap)-1)):
    cartier_pages.append(cartier_wrap[i].get("href"))
cartier_pages
# Out:
# ['/Cartier-Tank-Must..-Large-model..-quartz-movement..-steel..-leather-WSTA0041/p/17311178',
#  '/Cartier-Tank-Must..-Small-model..-quartz-movement..-steel-WSTA0051/p/17311180',
#  '/Cartier-Santos-De-Cartier-Watch-Large-Model..-Automatic-Movement..-Steel..-Interchangeable-Metal-And-Leather-Bracelets-WSSA0009/p/17310953',
#  '/Cartier-Santos-De-Cartier-Watch-Medium-Model..-Automatic-Movement..-Steel..-Interchangeable-Metal-And-Leather-Bracelets-WSSA0010/p/17310952',
#  '/Cartier--Santos-de-Cartier-watch..-Large-model..-automatic-movement..-steel..-interchangeable-metal-and-leather-bracelets-WSSA0013/p/17310997',
#  '/Cartier-Santos-De-Cartier-Watch-Large-Model..-Automatic-Movement..-Steel..-ADLC..-Interchangeable-Metal-And-Rubber-Bracelets-WSSA0037/p/17311097',
#  '/Cartier-Tank-Must..-Large-model..-quartz-movement..-steel-WSTA0052/p/17311181',
# ...

# %%
# define the lists to contain the scraped information

cwatch_code = []
cwatch_guarantee = []
cwatch_category = []
cwatch_markers = []
cwatch_strap =  []
cwatch_recipient = [] 
cwatch_movement = []
cwatch_dial = []
cwatch_case = []
cwatch_collection = []
cwatch_reference = []
cwatch_price = []
cwatch_brand = []



for c in cartier_pages[0:25]:
     # get the link utilizing the list created before, access the link and connect with soup 
    cartier_link = "https://www.watches-of-switzerland.co.uk" + c
    cartier_watch_access = requests.get(cartier_link, verify=False, headers=agent)
    time.sleep(5)
    cartier_watch_soup = soup(cartier_watch_access.text, 'html.parser')   
    # find the table of information for each watch
    time.sleep(6)
    
    # create a wrap to find the needed information
    cartier_table = cartier_watch_soup.find_all('span', {'class': 'specValue'})
    
    code = (cartier_table[0]).text
    cwatch_code.append(code)
    
    guarantee = (cartier_table[1]).text
    cwatch_guarantee.append(guarantee)
    
    category = (cartier_table[2]).text
    cwatch_category.append(category)
    
    markers = (cartier_table[4]).text
    cwatch_markers.append(markers)
    
    strap = (cartier_table[6]).text
    cwatch_strap.append(strap)
    
    recipient = (cartier_table[7]).text
    cwatch_recipient.append(recipient)
    
    movement = (cartier_table[8]).text
    cwatch_movement.append(movement)
    
    dial_color = (cartier_table[9]).text
    cwatch_dial.append(dial_color)
    
    case_material = (cartier_table[10]).text
    cwatch_case.append(case_material)
    
    collection = (cartier_table[12]).text
    cwatch_collection.append(collection)
    
    # create a wrap to find the needed information
    Cartier_spec = cartier_watch_soup.find_all('span',{'class': 'productManCode'})
    
    reference = Cartier_spec[0].text
    cwatch_reference.append(reference)
    
    # create a wrap to find the needed information
    Cartier_price = cartier_watch_soup.find_all('span',{'class': 'productPrice'})
    
    price = Cartier_price[0].get_text(strip=True)
    cwatch_price.append(price)
    # create a wrap to find the needed information
    Cartier_brand = cartier_watch_soup.find_all('span',{'class': 'productBrandName'})
    
    brand = Cartier_brand[0].get_text(strip=True)
    cwatch_brand.append(brand)

# %%
# create a dataframe and name the columns

C_watch_df5 = pd.DataFrame({'watch_code': cwatch_code,
                        'watch_brand': cwatch_brand,
                        'watch_collection': cwatch_collection,
                        'watch_reference': cwatch_reference,
                        'watch_price': cwatch_price,
                        'watch_movement': cwatch_movement,
                        'watch_case': cwatch_case,
                        'watch_dial': cwatch_dial,
                        'watch_strap': cwatch_strap,
                        'watch_markers': cwatch_markers,
                        'watch_guarantee': cwatch_guarantee,
                        'watch_category': cwatch_category,
                        'watch_recipient': cwatch_recipient
                       })
C_watch_df5
# Out:
#    watch_code watch_brand        watch_collection    watch_reference  \
# 0    17311178     Cartier               Tank Must           WSTA0041
# 1    17311180     Cartier               Tank Must           WSTA0051
# 2    17310953     Cartier       Santos de Cartier  WSSA0018/WSSA0009
# 3    17310952     Cartier       Santos de Cartier           WSSA0029
# 4    17310997     Cartier                17310997  WSSA0030/WSSA0013
# 5    17311097     Cartier       Santos de Cartier           WSSA0037
# 6    17311181     Cartier               Tank Must           WSTA0052
# 7    17311098     Cartier       Santos de Cartier           WSSA0039
# 8    17310192     Cartier          Tank Française           W51008Q3
# 9    17310956     Cartier       Santos de Cartier  W2SA0016/W2SA0007
# 10   17310957     Cartier       Santos de Cartier           W2SA0009
# 11   17310191     Cartier          Tank Française           WSTA0005
# 12   17311001     Cartier                17311001           WSSA0017
# ...

# %%
# remove the watches that do not have accurate information and reset the indexed

C_watch_df5.drop([4,12,13,14,15,19,20,21,22], inplace=True)
AP = AP.append(C_watch_df5)
AP.reset_index(inplace=True)
AP
# Out:
#     index watch_code      watch_brand          watch_collection  \
# 0       0   17580962  Audemars Piguet        Royal Oak Offshore
# 1       1   17580961  Audemars Piguet        Royal Oak Offshore
# 2       2   17580960  Audemars Piguet        Royal Oak Offshore
# 3       3   17580959  Audemars Piguet        Royal Oak Offshore
# 4       4   17580958  Audemars Piguet        Royal Oak Offshore
# 5       0   17580945  Audemars Piguet  Royal Oak Diver Offshore
# 6       1   17580910  Audemars Piguet  Royal Oak Diver Offshore
# 7       2   17580909  Audemars Piguet  Royal Oak Diver Offshore
# 8       0   17580888  Audemars Piguet        Royal Oak Offshore
# 9       1   17580887  Audemars Piguet        Royal Oak Offshore
# 10      0   17580873  Audemars Piguet                 Royal Oak
# 11      1   17580872  Audemars Piguet                 Royal Oak
# 12      0   17580869  Audemars Piguet                 Royal Oak
# 13      1   17580868  Audemars Piguet                 Royal Oak
# ...

# %%
# drop columns that are not needed

AP.drop(columns=['index'], inplace=True)

# %%
# save to csv

AP.to_csv('watches.csv')

# %%
AP
# Out:
#    watch_code      watch_brand          watch_collection  \
# 0    17580962  Audemars Piguet        Royal Oak Offshore
# 1    17580961  Audemars Piguet        Royal Oak Offshore
# 2    17580960  Audemars Piguet        Royal Oak Offshore
# 3    17580959  Audemars Piguet        Royal Oak Offshore
# 4    17580958  Audemars Piguet        Royal Oak Offshore
# 5    17580945  Audemars Piguet  Royal Oak Diver Offshore
# 6    17580910  Audemars Piguet  Royal Oak Diver Offshore
# 7    17580909  Audemars Piguet  Royal Oak Diver Offshore
# 8    17580888  Audemars Piguet        Royal Oak Offshore
# 9    17580887  Audemars Piguet        Royal Oak Offshore
# 10   17580873  Audemars Piguet                 Royal Oak
# 11   17580872  Audemars Piguet                 Royal Oak
# 12   17580869  Audemars Piguet                 Royal Oak
# 13   17580868  Audemars Piguet                 Royal Oak
# 14   17580867  Audemars Piguet                 Royal Oak
# ...

# %%
# save to parquet

AP.to_parquet('watches.parquet')
